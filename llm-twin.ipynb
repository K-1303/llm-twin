# %% [markdown]
# # Architectures Diagrams

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Monolithic batch pipeline architecture

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Stateless real-time architecture

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ML pipeline automation for CT (source: https://cloud.google.com/architecture/mlops-continuous-delivery-and-automation-pipelines-in-machine-learning)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# FTI pipelines architecture

# %% [markdown]
# ![image.png](attachment:image.png)
#
# LLM Twin high-level architecture

# %% [markdown]
# # Data Enginnering

# %% [markdown]
# ![image.png](attachment:image.png)
#
# LLM Twin’s data collection ETL pipeline architecture

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The relationship between the crawlers and the data categories

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The relationship between the provided links, the CrawlerDispatcher, and the
# crawlers
